# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import yfinance as yf
from pandas_datareader import data as pdr
from collections import deque
import random
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# Use yfinance to fetch data
yf.pdr_override()

# Fetching data for Apple Inc. (AAPL)
stock_data = pdr.get_data_yahoo('AAPL', start='2020-01-01', end='2021-01-01')

print(stock_data.head())
df = stock_data.copy()


name = 'Q-learning agent'

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen=1000)
        self.inventory = []
        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.keras.layers.Dense(256, activation=tf.nn.relu)(self.X)
        self.logits = tf.keras.layers.Dense(self.action_size)(feed)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(self.cost)
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(self.sess.run(self.logits, feed_dict={self.X: state})[0])

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict={self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict={self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict={self.X: X, self.Y: Y})
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f' % (t, self.trend[t], initial_money))
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print('day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                      % (t, self.trend[t], invest, initial_money))
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost, starting_money))
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.960464  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.251137  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.826851  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.484337  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.650345  132079200

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32

agent = Agent(state_size=window_size, window_size=window_size, trend=close, skip=skip, batch_size=batch_size)
agent.train(iterations=200, checkpoint=10, initial_money=initial_money)
import matplotlib.pyplot as plt

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32

agent = Agent(state_size=window_size, window_size=window_size, trend=close, skip=skip, batch_size=batch_size)
agent.train(iterations=200, checkpoint=10, initial_money=initial_money)

states_buy, states_sell, total_gains, invest = agent.buy(initial_money)

fig = plt.figure(figsize=(15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label='buying signal', markevery=states_buy)
plt.plot(close, 'v', markersize=10, color='k', label='selling signal', markevery=states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
# Out:
# epoch: 10, total rewards: 349.845016.3, cost: 0.860285, total money: 2267.507542
# epoch: 20, total rewards: 737.297504.3, cost: 0.379656, total money: 5259.725033
# epoch: 30, total rewards: 748.867496.3, cost: 0.249719, total money: 6053.775021
# epoch: 40, total rewards: 770.639999.3, cost: 0.198991, total money: 6110.335022
# epoch: 50, total rewards: 614.069988.3, cost: 0.152927, total money: 6796.765011
# epoch: 60, total rewards: 642.514996.3, cost: 0.128077, total money: 7229.315014
# epoch: 70, total rewards: 472.194996.3, cost: 0.111372, total money: 7616.765011
# epoch: 80, total rewards: 426.507496.3, cost: 0.097803, total money: 7829.240017
# epoch: 90, total rewards: 396.897503.3, cost: 0.085853, total money: 8295.437519
# epoch: 100, total rewards: 279.192516.3, cost: 0.079638, total money: 8428.722523
# epoch: 110, total rewards: 228.275013.3, cost: 0.073441, total money: 8608.295017
# epoch: 120, total rewards: 86.557522.3, cost: 0.068890, total money: 8682.317524
# epoch: 130, total rewards: 123.955021.3, cost: 0.067175, total money: 8501.155025
# epoch: 140, total rewards: 111.380024.3, cost: 0.074219, total money: 8935.920025
# epoch: 150, total rewards: 32.250019.3, cost: 0.058736, total money: 8856.790020
# epoch: 160, total rewards: 79.777523.3, cost: 0.057101, total money: 8787.817524
# epoch: 170, total rewards: 81.307522.3, cost: 0.125943, total money: 8905.847523
# epoch: 180, total rewards: 98.010021.3, cost: 0.059577, total money: 8119.690029
# epoch: 190, total rewards: 139.785023.3, cost: 0.052389, total money: 8620.375027
# epoch: 200, total rewards: 161.157520.3, cost: 0.052753, total money: 8423.187527
# epoch: 10, total rewards: 7.847538.3, cost: 0.369769, total money: 10007.847538
# epoch: 20, total rewards: 11.407520.3, cost: 0.269497, total money: 10011.407520
# epoch: 30, total rewards: 36.372528.3, cost: 0.210371, total money: 10036.372528
# epoch: 40, total rewards: 45.265030.3, cost: 0.172167, total money: 10045.265030
# epoch: 50, total rewards: 34.770027.3, cost: 0.147464, total money: 10034.770027
# epoch: 60, total rewards: 50.202515.3, cost: 0.132418, total money: 10050.202515
# epoch: 70, total rewards: 55.552513.3, cost: 0.109133, total money: 10055.552513
# epoch: 80, total rewards: 60.827507.3, cost: 0.099028, total money: 10060.827507
# epoch: 90, total rewards: 84.542519.3, cost: 0.101775, total money: 10084.542519
# epoch: 100, total rewards: 72.237511.3, cost: 0.083268, total money: 10072.237511
# epoch: 110, total rewards: 78.132507.3, cost: 0.077501, total money: 10078.132507
# epoch: 120, total rewards: 83.610008.3, cost: 0.072494, total money: 10083.610008
# epoch: 130, total rewards: 85.067505.3, cost: 0.068069, total money: 10085.067505
# epoch: 140, total rewards: 83.610008.3, cost: 0.064230, total money: 10083.610008
# epoch: 150, total rewards: 77.050003.3, cost: 0.060830, total money: 10077.050003
# epoch: 160, total rewards: 64.890007.3, cost: 0.057815, total money: 10064.890007
# epoch: 170, total rewards: 75.030006.3, cost: 0.055000, total money: 10075.030006
# epoch: 180, total rewards: 97.815018.3, cost: 0.052467, total money: 10097.815018
# epoch: 190, total rewards: 103.677513.3, cost: 0.050130, total money: 10103.677513
# epoch: 200, total rewards: 98.407516.3, cost: 0.048091, total money: 10098.407516
# day 1: buy 1 unit at price 74.357498, total balance 9925.642502
# day 2, sell 1 unit at price 74.949997, investment 0.796825 %, total balance 10000.592499,
# day 8: buy 1 unit at price 78.169998, total balance 9922.422501
# day 9: buy 1 unit at price 77.834999, total balance 9844.587502
# day 10, sell 1 unit at price 78.809998, investment 0.818728 %, total balance 9923.397499,
# day 11, sell 1 unit at price 79.682503, investment 2.373616 %, total balance 10003.080002,
# day 30: buy 1 unit at price 81.237503, total balance 9921.842499
# day 31, sell 1 unit at price 79.750000, investment -1.831055 %, total balance 10001.592499,
# day 33: buy 1 unit at price 80.074997, total balance 9921.517502
# day 35: buy 1 unit at price 74.544998, total balance 9846.972504
# day 36: buy 1 unit at price 72.019997, total balance 9774.952507
# day 37: buy 1 unit at price 73.162498, total balance 9701.790009
# day 39, sell 1 unit at price 68.339996, investment -14.655012 %, total balance 9770.130005,
# day 41, sell 1 unit at price 72.330002, investment -2.971355 %, total balance 9842.460007,
# day 42, sell 1 unit at price 75.684998, investment 5.088866 %, total balance 9918.145004,
# day 43: buy 1 unit at price 73.230003, total balance 9844.915001
# day 44, sell 1 unit at price 72.257500, investment -1.236971 %, total balance 9917.172501,
# day 45: buy 1 unit at price 66.542503, total balance 9850.629997
# day 46: buy 1 unit at price 71.334999, total balance 9779.294998
# day 51, sell 1 unit at price 63.215000, investment -13.676093 %, total balance 9842.509998,
# day 52: buy 1 unit at price 61.667500, total balance 9780.842499
# day 54, sell 1 unit at price 57.310001, investment -13.874594 %, total balance 9838.152500,
# day 55, sell 1 unit at price 56.092499, investment -21.367492 %, total balance 9894.244999,
# day 56, sell 1 unit at price 61.720001, investment 0.085137 %, total balance 9955.965000,
# day 61: buy 1 unit at price 63.572498, total balance 9892.392502
# day 62: buy 1 unit at price 60.227501, total balance 9832.165001
# day 66, sell 1 unit at price 64.857498, investment 2.021314 %, total balance 9897.022499,
# day 67, sell 1 unit at price 66.517502, investment 10.443736 %, total balance 9963.540001,
# day 69: buy 1 unit at price 68.312500, total balance 9895.227501
# day 70, sell 1 unit at price 71.762497, investment 5.050316 %, total balance 9966.989998,
# day 71: buy 1 unit at price 71.107498, total balance 9895.882500
# day 75, sell 1 unit at price 67.092499, investment -5.646380 %, total balance 9962.974998,
# day 80: buy 1 unit at price 69.644997, total balance 9893.330002
# day 81, sell 1 unit at price 71.932503, investment 3.284523 %, total balance 9965.262505,
# day 84: buy 1 unit at price 73.290001, total balance 9891.972504
# day 85: buy 1 unit at price 74.389999, total balance 9817.582504
# day 86, sell 1 unit at price 75.157501, investment 2.548097 %, total balance 9892.740005,
# day 88, sell 1 unit at price 77.532501, investment 4.224361 %, total balance 9970.272507,
# day 94: buy 1 unit at price 78.739998, total balance 9891.532509
# day 95: buy 1 unit at price 78.285004, total balance 9813.247505
# day 96: buy 1 unit at price 79.807503, total balance 9733.440002
# day 97, sell 1 unit at price 79.212502, investment 0.600081 %, total balance 9812.652504,
# day 98, sell 1 unit at price 79.722504, investment 1.836239 %, total balance 9892.375008,
# day 99: buy 1 unit at price 79.182503, total balance 9813.192505
# day 100: buy 1 unit at price 79.527496, total balance 9733.665009
# day 101: buy 1 unit at price 79.562500, total balance 9654.102509
# day 102: buy 1 unit at price 79.485001, total balance 9574.617508
# day 104, sell 1 unit at price 80.834999, investment 1.287468 %, total balance 9655.452507,
# day 105, sell 1 unit at price 81.279999, investment 2.648939 %, total balance 9736.732506,
# day 106, sell 1 unit at price 80.580002, investment 1.323449 %, total balance 9817.312508,
# day 107, sell 1 unit at price 82.875000, investment 4.163394 %, total balance 9900.187508,
# day 109, sell 1 unit at price 85.997498, investment 8.193366 %, total balance 9986.185005,
# day 111: buy 1 unit at price 83.974998, total balance 9902.210007
# day 113, sell 1 unit at price 85.747498, investment 2.110746 %, total balance 9987.957504,
# day 120: buy 1 unit at price 90.014999, total balance 9897.942505
# day 121: buy 1 unit at price 91.209999, total balance 9806.732506
# day 122, sell 1 unit at price 88.407501, investment -1.785811 %, total balance 9895.140007,
# day 123: buy 1 unit at price 90.445000, total balance 9804.695007
# day 124, sell 1 unit at price 91.199997, investment -0.010966 %, total balance 9895.895004,
# day 125, sell 1 unit at price 91.027496, investment 0.644034 %, total balance 9986.922501,
# day 126: buy 1 unit at price 91.027496, total balance 9895.895004
# day 127, sell 1 unit at price 93.462502, investment 2.675022 %, total balance 9989.357506,
# day 129: buy 1 unit at price 95.342499, total balance 9894.015007
# day 130, sell 1 unit at price 95.752502, investment 0.430032 %, total balance 9989.767509,
# day 131: buy 1 unit at price 95.919998, total balance 9893.847511
# day 132: buy 1 unit at price 95.477501, total balance 9798.370010
# day 133: buy 1 unit at price 97.057503, total balance 9701.312508
# day 134, sell 1 unit at price 97.724998, investment 1.881777 %, total balance 9799.037506,
# day 135, sell 1 unit at price 96.522499, investment 1.094497 %, total balance 9895.560005,
# day 138: buy 1 unit at price 97.000000, total balance 9798.560005
# day 139, sell 1 unit at price 97.272499, investment 0.221514 %, total balance 9895.832504,
# day 140: buy 1 unit at price 92.845001, total balance 9802.987503
# day 141: buy 1 unit at price 92.614998, total balance 9710.372505
# day 142, sell 1 unit at price 94.809998, investment -2.257734 %, total balance 9805.182503,
# day 143: buy 1 unit at price 93.252502, total balance 9711.930000
# day 144, sell 1 unit at price 95.040001, investment 2.364155 %, total balance 9806.970001,
# day 146, sell 1 unit at price 106.260002, investment 14.733040 %, total balance 9913.230003,
# day 147, sell 1 unit at price 108.937500, investment 16.819921 %, total balance 10022.167503,
# day 152: buy 1 unit at price 112.727501, total balance 9909.440002
# day 154, sell 1 unit at price 113.010002, investment 0.250605 %, total balance 10022.450005,
# day 159: buy 1 unit at price 115.707497, total balance 9906.742508
# day 161, sell 1 unit at price 124.370003, investment 7.486556 %, total balance 10031.112511,
# day 166: buy 1 unit at price 124.807503, total balance 9906.305008
# day 167, sell 1 unit at price 129.039993, investment 3.391215 %, total balance 10035.345001,
# day 172: buy 1 unit at price 112.820000, total balance 9922.525002
# day 173, sell 1 unit at price 117.320000, investment 3.988655 %, total balance 10039.845001,
# day 180: buy 1 unit at price 106.839996, total balance 9933.005005
# day 181, sell 1 unit at price 110.080002, investment 3.032577 %, total balance 10043.085007,
# day 191: buy 1 unit at price 116.500000, total balance 9926.585007
# day 192, sell 1 unit at price 113.160004, investment -2.866950 %, total balance 10039.745010,
# day 197: buy 1 unit at price 121.099998, total balance 9918.645012
# day 198, sell 1 unit at price 121.190002, investment 0.074322 %, total balance 10039.835014,
# day 200: buy 1 unit at price 119.019997, total balance 9920.815018
# day 201, sell 1 unit at price 115.980003, investment -2.554187 %, total balance 10036.795021,
# day 208: buy 1 unit at price 111.199997, total balance 9925.595024
# day 210: buy 1 unit at price 108.860001, total balance 9816.735023
# day 211: buy 1 unit at price 108.769997, total balance 9707.965027
# day 213, sell 1 unit at price 114.949997, investment 3.372302 %, total balance 9822.915024,
# day 214, sell 1 unit at price 119.029999, investment 9.342273 %, total balance 9941.945023,
# day 215: buy 1 unit at price 118.690002, total balance 9823.255020
# day 216, sell 1 unit at price 116.320000, investment 6.941255 %, total balance 9939.575020,
# day 217, sell 1 unit at price 115.970001, investment -2.291685 %, total balance 10055.545021,
# day 218: buy 1 unit at price 119.489998, total balance 9936.055023
# day 220: buy 1 unit at price 119.260002, total balance 9816.795021
# day 223, sell 1 unit at price 118.029999, investment -1.221859 %, total balance 9934.825020,
# day 224, sell 1 unit at price 118.639999, investment -0.519875 %, total balance 10053.465019,
# day 232: buy 1 unit at price 123.080002, total balance 9930.385017
# day 233: buy 1 unit at price 122.940002, total balance 9807.445015
# day 234, sell 1 unit at price 122.250000, investment -0.674360 %, total balance 9929.695015,
# day 235: buy 1 unit at price 123.750000, total balance 9805.945015
# day 236: buy 1 unit at price 124.379997, total balance 9681.565018
# day 237: buy 1 unit at price 121.779999, total balance 9559.785019
# day 239, sell 1 unit at price 122.410004, investment -0.431104 %, total balance 9682.195023,
# day 245, sell 1 unit at price 128.229996, investment 3.620199 %, total balance 9810.425018,
# day 246, sell 1 unit at price 131.880005, investment 6.029915 %, total balance 9942.305023,
# day 248, sell 1 unit at price 131.970001, investment 8.367550 %, total balance 10074.275024,
